# %%
import asyncio
import json
import os
from utils import *
from TikTokApi import TikTokApi


os.chdir("/Users/vophuhan/Everything/University/Năm 4/Semester 2/Ứng dụng Phân tích dữ liệu thông minh/21KHDL-TikTok-Analytics")
# Define data directories
USER_LISTS_DIR = "data/user_lists/hashtags"

# Define filtering parameters
MIN_LIKES = 10000
MIN_VIDEOS = 2
MIN_FOLLOWERS = 0

# Define evaluation parameters
TIME_WINDOW_DAYS = 90
MIN_VIDEOS_PER_WEEK = 1

MIN_VIEWS = 200000
MIN_ENGAGEMENT_RATE = 0.05
MIN_VALID_VIDEOS = 4

# Input file with hashtags
hashtag_file = os.path.join(USER_LISTS_DIR, "hashtag_amthuc.txt")

# %%
# Read hashtags from a file
hashtags = read_usernames_from_file(hashtag_file)
hashtags = set(hashtags)

if not hashtags:
    print("No hashtags found in file.")
else:
    print(f"📌 Loaded {len(hashtags)} hashtags from {hashtag_file}")

# Display loaded hashtags
hashtags
# Out:
# 📌 Loaded 13 hashtags from data/user_lists/hashtags/hashtag_amthuc.txt
# {'amthuc',
#  'ancungtiktok',
#  'anvat',
#  'anvatsaigon',
#  'buacomgiadinh',
#  'diadiemanuong',
#  'eatclean',
#  'foodreview',
#  'foodtour',
#  'monngon',
#  'reviewanngon',
#  'reviewanuongsaigon',
#  'saigonfood'}

# %%
# # Fetch videos for each hashtag and save
# print("\n📥 Fetching videos for hashtags...")

# hashtag_videos = await get_videos_for_hashtags(hashtags, count=1000, save=True)

# # Check the first few results
# list(hashtag_videos.keys())[:5]

# %%
# Define the directory containing user list files
DATA_DIR = "data/test/hashtags"

hashtag_videos = {}

# List all files in the directory
for filename in os.listdir(DATA_DIR):
    file_path = os.path.join(DATA_DIR, filename)
    # Read usernames from the file
    with open(file_path, "r") as file:
        json_data = json.load(file)

    hashtag_videos[filename[:-5]] = json_data

# %%
# Create directory if not exists
os.makedirs(USER_LISTS_DIR, exist_ok=True)

filtered_users = {}

print("\n🔍 Filtering users based on video criteria...")
for hashtag, videos in hashtag_videos.items():
    filtered = filter_users_by_video_criteria(
        videos, MIN_LIKES, MIN_VIDEOS, MIN_FOLLOWERS)
    filtered_users[hashtag] = filtered

    # Save filtered users as text file
    user_list_file = os.path.join(USER_LISTS_DIR, f"users_{hashtag}.txt")
    write_list_to_file(user_list_file, filtered)
    print(f"✅ Saved filtered users to {user_list_file}")

# Display the first few filtered users
# len(filtered_users)
# Out:
# 🔍 Filtering users based on video criteria...
# Successfully wrote 21 items to data/user_lists/hashtags/users_anvat.txt
# ✅ Saved filtered users to data/user_lists/hashtags/users_anvat.txt
# Successfully wrote 36 items to data/user_lists/hashtags/users_amthuc.txt
# ✅ Saved filtered users to data/user_lists/hashtags/users_amthuc.txt
# Successfully wrote 39 items to data/user_lists/hashtags/users_foodtour.txt
# ✅ Saved filtered users to data/user_lists/hashtags/users_foodtour.txt
# Successfully wrote 59 items to data/user_lists/hashtags/users_foodreview.txt
# ✅ Saved filtered users to data/user_lists/hashtags/users_foodreview.txt
# Successfully wrote 18 items to data/user_lists/hashtags/users_reviewanuongsaigon.txt
# ✅ Saved filtered users to data/user_lists/hashtags/users_reviewanuongsaigon.txt
# Successfully wrote 23 items to data/user_lists/hashtags/users_eatclean.txt
# ✅ Saved filtered users to data/user_lists/hashtags/users_eatclean.txt
# Successfully wrote 9 items to data/user_lists/hashtags/users_diadiemanuong.txt
# ✅ Saved filtered users to data/user_lists/hashtags/users_diadiemanuong.txt
# Successfully wrote 48 items to data/user_lists/hashtags/users_monngon.txt
# ✅ Saved filtered users to data/user_lists/hashtags/users_monngon.txt
# Successfully wrote 18 items to data/user_lists/hashtags/users_buacomgiadinh.txt
# ✅ Saved filtered users to data/user_lists/hashtags/users_buacomgiadinh.txt
# Successfully wrote 34 items to data/user_lists/hashtags/users_ancungtiktok.txt
# ✅ Saved filtered users to data/user_lists/hashtags/users_ancungtiktok.txt
# Successfully wrote 40 items to data/user_lists/hashtags/users_reviewanngon.txt
# ✅ Saved filtered users to data/user_lists/hashtags/users_reviewanngon.txt
# Successfully wrote 37 items to data/user_lists/hashtags/users_anvatsaigon.txt
# ✅ Saved filtered users to data/user_lists/hashtags/users_anvatsaigon.txt
# Successfully wrote 36 items to data/user_lists/hashtags/users_saigonfood.txt
# ✅ Saved filtered users to data/user_lists/hashtags/users_saigonfood.txt

# %%
# Define the directory containing user list files
USER_LISTS_DIR = "data/user_lists/hashtags"

# Initialize a set to store unique users
unique_users = set()

# List all files in the directory
for filename in os.listdir(USER_LISTS_DIR):
    if filename.startswith("users_") and filename.endswith(".txt"):
        file_path = os.path.join(USER_LISTS_DIR, filename)

        # Read usernames from the file
        with open(file_path, "r", encoding="utf-8") as file:
            users = file.read().splitlines()
            # Add users to the set to ensure uniqueness
            unique_users.update(users)

# Convert set to sorted list (optional)
unique_users_list = sorted(unique_users)

# Print results
print(f"✅ Found {len(unique_users_list)} unique users.")
print(unique_users_list[:10])  # Show first 10 users for preview
# Out:
# ✅ Found 266 unique users.
# ['.banhsukem', '1108ng', '1phutsaigon', '30days__giamcanlanhmanh', '_tidofood', '_trinhhavi_', '_ttqueen', 'along_foods', 'amthuc48h', 'amthuc_vietnam3']

# %%
# Split users into chunks of 30 per batch
BATCH_SIZE = 30
user_batches = [unique_users_list[i:i + BATCH_SIZE]
                for i in range(0, len(unique_users_list), BATCH_SIZE)]

# Check the number of batches
print(f"✅ Total batches: {len(user_batches)}")
users_batch = [i for i in user_batches]
final_users_cell = ["" for _ in range(len(user_batches))]
user_video_stats_cell = [{} for _ in range(len(user_batches))]
# Out:
# ✅ Total batches: 9

# %%
X = 0
print(f"\n📊 Evaluating user performance - Batch {X}")

final_users_cell[X], user_video_stats_cell[X] = await evaluate_user_performance(
    users_batch[X],
    TIME_WINDOW_DAYS,
    MIN_VIDEOS_PER_WEEK,
    MIN_VIEWS,
    MIN_ENGAGEMENT_RATE,
    MIN_VALID_VIDEOS
)

print(f"\n✅ {len(final_users_cell[X])} users passed in Batch {X}.")
# Out:
# 📊 Evaluating user performance - Batch 0
#
# --- Attempt 1/5: 30 users ---
#
# ✅ All users processed successfully!
#
# ✅ 12 users passed in Batch 0.

# %%
X = 1
print(f"\n📊 Evaluating user performance - Batch {X}")

final_users_cell[X], user_video_stats_cell[X] = await evaluate_user_performance(
    users_batch[X],
    TIME_WINDOW_DAYS,
    MIN_VIDEOS_PER_WEEK,
    MIN_VIEWS,
    MIN_ENGAGEMENT_RATE,
    MIN_VALID_VIDEOS
)

print(f"\n✅ {len(final_users_cell[X])} users passed in Batch {X}.")
# Out:
# 📊 Evaluating user performance - Batch 1
#
# --- Attempt 1/5: 30 users ---
#
# ✅ All users processed successfully!
#
# ✅ 7 users passed in Batch 1.

# %%
X = 2
print(f"\n📊 Evaluating user performance - Batch {X}")

final_users_cell[X], user_video_stats_cell[X] = await evaluate_user_performance(
    users_batch[X],
    TIME_WINDOW_DAYS,
    MIN_VIDEOS_PER_WEEK,
    MIN_VIEWS,
    MIN_ENGAGEMENT_RATE,
    MIN_VALID_VIDEOS
)

print(f"\n✅ {len(final_users_cell[X])} users passed in Batch {X}.")
# Out:
# 📊 Evaluating user performance - Batch 2
#
# --- Attempt 1/5: 30 users ---
#
# ✅ All users processed successfully!
#
# ✅ 8 users passed in Batch 2.

# %%
X = 3
print(f"\n📊 Evaluating user performance - Batch {X}")

final_users_cell[X], user_video_stats_cell[X] = await evaluate_user_performance(
    users_batch[X],
    TIME_WINDOW_DAYS,
    MIN_VIDEOS_PER_WEEK,
    MIN_VIEWS,
    MIN_ENGAGEMENT_RATE,
    MIN_VALID_VIDEOS
)

print(f"\n✅ {len(final_users_cell[X])} users passed in Batch {X}.")
# Out:
# 📊 Evaluating user performance - Batch 3
#
# --- Attempt 1/5: 30 users ---
#
# ✅ All users processed successfully!
#
# ✅ 12 users passed in Batch 3.

# %%
X = 4
print(f"\n📊 Evaluating user performance - Batch {X}")

final_users_cell[X], user_video_stats_cell[X] = await evaluate_user_performance(
    users_batch[X],
    TIME_WINDOW_DAYS,
    MIN_VIDEOS_PER_WEEK,
    MIN_VIEWS,
    MIN_ENGAGEMENT_RATE,
    MIN_VALID_VIDEOS
)

print(f"\n✅ {len(final_users_cell[X])} users passed in Batch {X}.")
# Out:
# 📊 Evaluating user performance - Batch 4
#
# --- Attempt 1/5: 30 users ---
#
# ✅ All users processed successfully!
#
# ✅ 6 users passed in Batch 4.

# %%
X = 5
print(f"\n📊 Evaluating user performance - Batch {X}")

final_users_cell[X], user_video_stats_cell[X] = await evaluate_user_performance(
    users_batch[X],
    TIME_WINDOW_DAYS,
    MIN_VIDEOS_PER_WEEK,
    MIN_VIEWS,
    MIN_ENGAGEMENT_RATE,
    MIN_VALID_VIDEOS
)

print(f"\n✅ {len(final_users_cell[X])} users passed in Batch {X}.")
# Out:
# 📊 Evaluating user performance - Batch 5
#
# --- Attempt 1/5: 30 users ---
#
# ✅ All users processed successfully!
#
# ✅ 8 users passed in Batch 5.

# %%
X = 6
print(f"\n📊 Evaluating user performance - Batch {X}")

final_users_cell[X], user_video_stats_cell[X] = await evaluate_user_performance(
    users_batch[X],
    TIME_WINDOW_DAYS,
    MIN_VIDEOS_PER_WEEK,
    MIN_VIEWS,
    MIN_ENGAGEMENT_RATE,
    MIN_VALID_VIDEOS
)

print(f"\n✅ {len(final_users_cell[X])} users passed in Batch {X}.")
# Out:
# 📊 Evaluating user performance - Batch 6
#
# --- Attempt 1/5: 30 users ---
#
# ✅ All users processed successfully!
#
# ✅ 7 users passed in Batch 6.

# %%
X = 7
print(f"\n📊 Evaluating user performance - Batch {X}")

final_users_cell[X], user_video_stats_cell[X] = await evaluate_user_performance(
    users_batch[X],
    TIME_WINDOW_DAYS,
    MIN_VIDEOS_PER_WEEK,
    MIN_VIEWS,
    MIN_ENGAGEMENT_RATE,
    MIN_VALID_VIDEOS
)

print(f"\n✅ {len(final_users_cell[X])} users passed in Batch {X}.")
# Out:
# 📊 Evaluating user performance - Batch 7
#
# --- Attempt 1/5: 30 users ---
#
# ✅ All users processed successfully!
#
# ✅ 9 users passed in Batch 7.

# %%
X = 8
print(f"\n📊 Evaluating user performance - Batch {X}")

final_users_cell[X], user_video_stats_cell[X] = await evaluate_user_performance(
    users_batch[X],
    TIME_WINDOW_DAYS,
    MIN_VIDEOS_PER_WEEK,
    MIN_VIEWS,
    MIN_ENGAGEMENT_RATE,
    MIN_VALID_VIDEOS
)

print(f"\n✅ {len(final_users_cell[X])} users passed in Batch {X}.")
# Out:
# 📊 Evaluating user performance - Batch 8
#
# --- Attempt 1/5: 26 users ---
#
# ✅ All users processed successfully!
#
# ✅ 8 users passed in Batch 8.

# %%
# Combine all final users
all_final_users = []
for i in final_users_cell:
    all_final_users.extend(i)

# Merge user video stats from all batches
all_user_video_stats = {}
for i in user_video_stats_cell:
    all_user_video_stats.update(i)

print(f"\n✅ Total final users after merging: {len(all_final_users)}")
# Out:
# ✅ Total final users after merging: 77

# %%
# Define final output file paths
final_users_txt = os.path.join(USER_LISTS_DIR, "final_filtered_users1.txt")
final_users_json = os.path.join(USER_LISTS_DIR, "final_filtered_users1.json")

# Save the final list of users
write_list_to_file(final_users_txt, all_final_users)

# Save user performance data
with open(final_users_json, "w") as f:
    json.dump(all_user_video_stats, f, indent=4)

print(f"✅ Final filtered users saved to {final_users_txt}")
print(f"✅ User performance data saved to {final_users_json}")
# Out:
# Successfully wrote 77 items to data/user_lists/hashtags/final_filtered_users1.txt
# ✅ Final filtered users saved to data/user_lists/hashtags/final_filtered_users1.txt
# ✅ User performance data saved to data/user_lists/hashtags/final_filtered_users1.json

# %%
crawl_path1 = "data/user_lists/hashtags/final_filtered_users1.txt"
crawl_path = "data/user_lists/hashtags/final_filtered_users.txt"
my_path = "data/user_lists/user_list_amthuc.txt"

with open(crawl_path, "r") as file:
    crawl_users = file.read().splitlines()

with open(crawl_path1, "r") as file:
    crawl_users1 = file.read().splitlines()

with open(my_path, "r") as file:
    my_users = file.read().splitlines()

write_list_to_file("data/user_lists/user_list_amthuc.txt",
                   list(set(crawl_users1 + my_users)))
# Out:
# Successfully wrote 109 items to data/user_lists/user_list_amthuc.txt
